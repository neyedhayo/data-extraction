# %%
import pandas as pd

# %%
data = pd.read_csv('third-new-extracted-data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/lordmax/Downloads/machine-learning-projects/Vale projects/data-extraction/main data/main-check-file.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/home/lordmax/Downloads/machine-learning-projects/Vale%20projects/data-extraction/main%20data/main-check-file.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_csv('third-new-extracted-data.csv')
#
# ...

# %%
data
# Out:
#                 textBox2 initiatingDateTimeCaptionTextBox  \
# 0    Transactions Report                             Date
# 1    Transactions Report                             Date
# 2    Transactions Report                             Date
# 3    Transactions Report                             Date
# 4    Transactions Report                             Date
# ..                   ...                              ...
# 186  Transactions Report                             Date
# 187  Transactions Report                             Date
# 188  Transactions Report                             Date
# 189  Transactions Report                             Date
# 190  Transactions Report                             Date
#
#     transactionReferenceNumberCaptionTextBox depositSlipCaptionTextBox  \
# 0                      Transaction Reference               Customer Id
# 1                      Transaction Reference               Customer Id
# ...

# %%
data.to_excel('eighth-report.xlsx', index=False)
